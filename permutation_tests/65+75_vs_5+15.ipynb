# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nilearn import image, plotting
from nilearn.glm.second_level import SecondLevelModel
from nilearn.input_data import NiftiMasker
# Out:
# C:\Users\ducat\AppData\Local\Temp\ipykernel_6956\1902100879.py:6: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   from nilearn.input_data import NiftiMasker

# %%
contrast_tested = '65_+_75_over_5_+_15'

subject_ids = {2, 4, 5, 6, 9, 11, 14, 15, 17, 19}
subject_imgs = [f"contrasts/smoothed_3mm/sub-{i}-{contrast_tested}.nii.gz" for i in subject_ids]

n_permutations = 10000

n_subjects = len(subject_imgs)
design_matrix = pd.DataFrame(
    [1] * n_subjects,
    columns=["intercept"]
)

# %%
# Fit the REAL second-level model
second_level_model = SecondLevelModel()
second_level_model.fit(subject_imgs, design_matrix=design_matrix)

# Get observed t-map
observed_t_map = second_level_model.compute_contrast(
    second_level_contrast="intercept",
    output_type="stat"          # Returns t-statistic map
)

print("Observed t-map computed")
print(f"Max t-value observed: {observed_t_map.get_fdata().max():.3f}")
# Out:
# Observed t-map computed
# Max t-value observed: 7.702

# %%
masker = NiftiMasker(
    mask_strategy="whole-brain-template",
    smoothing_fwhm=6.0,
    standardize=False
)

subject_data = masker.fit_transform(subject_imgs)
# Shape: (n_subjects, n_voxels)
print(f"Data shape: {subject_data.shape}")

observed_t_masked = masker.transform(observed_t_map).squeeze()
# Out:
# Data shape: (10, 51075)

# %%
from joblib import Parallel, delayed

def run_permutation_parallel(i, subject_data, design_matrix, masker):
    rng = np.random.RandomState(i)
    n_subjects = subject_data.shape[0]

    signs = rng.choice([-1, 1], size=n_subjects)
    permuted_data = subject_data * signs[:, np.newaxis]

    permuted_imgs = masker.inverse_transform(permuted_data)
    permuted_imgs_list = list(image.iter_img(permuted_imgs))

    perm_model = SecondLevelModel(smoothing_fwhm=None)
    perm_model.fit(permuted_imgs_list, design_matrix=design_matrix)

    perm_t_map = perm_model.compute_contrast(
        second_level_contrast="intercept",
        output_type="stat"
    )

    return masker.transform(perm_t_map).squeeze().max()


# Run in parallel using all available cores
null_distribution = Parallel(n_jobs=-1, verbose=10)(
    delayed(run_permutation_parallel)(
        i, subject_data, design_matrix, masker
    )
    for i in range(n_permutations)
)

null_distribution = np.array(null_distribution)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 745 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 825 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 909 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 952 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 1042 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 1089 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 1185 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 1285 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 1336 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 1389 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 1497 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 1552 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 1609 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 1666 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 1725 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 1845 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 1906 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 2032 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 2097 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 2162 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 2229 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 2296 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 2365 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 2505 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 2649 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 2722 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 2797 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 2872 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 2949 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 3026 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 3105 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 3265 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 3346 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 3429 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 3512 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 3597 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 3682 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done 3769 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 3856 tasks      | elapsed: 22.9min
# [Parallel(n_jobs=-1)]: Done 3945 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed: 23.9min
# [Parallel(n_jobs=-1)]: Done 4125 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=-1)]: Done 4216 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 4309 tasks      | elapsed: 25.5min
# [Parallel(n_jobs=-1)]: Done 4402 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 4497 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 4592 tasks      | elapsed: 27.1min
# [Parallel(n_jobs=-1)]: Done 4689 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 4786 tasks      | elapsed: 28.2min
# [Parallel(n_jobs=-1)]: Done 4885 tasks      | elapsed: 28.8min
# [Parallel(n_jobs=-1)]: Done 4984 tasks      | elapsed: 29.3min
# [Parallel(n_jobs=-1)]: Done 5085 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done 5186 tasks      | elapsed: 30.5min
# [Parallel(n_jobs=-1)]: Done 5289 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-1)]: Done 5392 tasks      | elapsed: 31.8min
# [Parallel(n_jobs=-1)]: Done 5497 tasks      | elapsed: 32.4min
# [Parallel(n_jobs=-1)]: Done 5602 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 5709 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 5816 tasks      | elapsed: 34.2min
# [Parallel(n_jobs=-1)]: Done 5925 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 6034 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done 6145 tasks      | elapsed: 36.2min
# [Parallel(n_jobs=-1)]: Done 6256 tasks      | elapsed: 36.8min
# [Parallel(n_jobs=-1)]: Done 6369 tasks      | elapsed: 37.5min
# [Parallel(n_jobs=-1)]: Done 6482 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 6597 tasks      | elapsed: 38.8min
# [Parallel(n_jobs=-1)]: Done 6712 tasks      | elapsed: 39.5min
# [Parallel(n_jobs=-1)]: Done 6829 tasks      | elapsed: 40.2min
# [Parallel(n_jobs=-1)]: Done 6946 tasks      | elapsed: 40.8min
# [Parallel(n_jobs=-1)]: Done 7065 tasks      | elapsed: 41.5min
# [Parallel(n_jobs=-1)]: Done 7184 tasks      | elapsed: 42.2min
# [Parallel(n_jobs=-1)]: Done 7305 tasks      | elapsed: 43.0min
# [Parallel(n_jobs=-1)]: Done 7426 tasks      | elapsed: 43.7min
# [Parallel(n_jobs=-1)]: Done 7549 tasks      | elapsed: 44.4min
# [Parallel(n_jobs=-1)]: Done 7672 tasks      | elapsed: 45.2min
# [Parallel(n_jobs=-1)]: Done 7797 tasks      | elapsed: 45.9min
# [Parallel(n_jobs=-1)]: Done 7922 tasks      | elapsed: 46.6min
# [Parallel(n_jobs=-1)]: Done 8049 tasks      | elapsed: 47.3min
# [Parallel(n_jobs=-1)]: Done 8176 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 8305 tasks      | elapsed: 48.9min
# [Parallel(n_jobs=-1)]: Done 8434 tasks      | elapsed: 49.7min
# [Parallel(n_jobs=-1)]: Done 8565 tasks      | elapsed: 50.5min
# [Parallel(n_jobs=-1)]: Done 8696 tasks      | elapsed: 51.3min
# [Parallel(n_jobs=-1)]: Done 8829 tasks      | elapsed: 52.0min
# [Parallel(n_jobs=-1)]: Done 8962 tasks      | elapsed: 52.8min
# [Parallel(n_jobs=-1)]: Done 9097 tasks      | elapsed: 53.6min
# [Parallel(n_jobs=-1)]: Done 9232 tasks      | elapsed: 54.3min
# [Parallel(n_jobs=-1)]: Done 9369 tasks      | elapsed: 55.1min
# [Parallel(n_jobs=-1)]: Done 9506 tasks      | elapsed: 55.9min
# [Parallel(n_jobs=-1)]: Done 9645 tasks      | elapsed: 56.7min
# [Parallel(n_jobs=-1)]: Done 9784 tasks      | elapsed: 57.6min
# [Parallel(n_jobs=-1)]: Done 9925 tasks      | elapsed: 58.4min
# [Parallel(n_jobs=-1)]: Done 10000 out of 10000 | elapsed: 58.9min finished

# %%
# FWE-corrected threshold (95th percentile of null distribution)
threshold_fwe_05 = np.percentile(null_distribution, 95)
threshold_fwe_01 = np.percentile(null_distribution, 99)

print(f"FWE-corrected threshold (p<0.05): t > {threshold_fwe_05:.3f}")
print(f"FWE-corrected threshold (p<0.01): t > {threshold_fwe_01:.3f}")

# Compute voxel-wise permutation p-values
# For each voxel: proportion of permutations exceeding observed t
p_values = np.array([
    np.mean(null_distribution >= t)
    for t in observed_t_masked
])

# Convert to -log10(p) for visualization (same as nilearn output)
# Add small epsilon to avoid log(0)
log_p_map_data = -np.log10(p_values + 1e-10)

# Reconstruct log-p image
log_p_map = masker.inverse_transform(log_p_map_data)
# Out:
# FWE-corrected threshold (p<0.05): t > 4.111
# FWE-corrected threshold (p<0.01): t > 4.396

# %%
(p_values.min(), p_values.max())
# Out:
# (np.float64(0.8738), np.float64(1.0))

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# --- Plot 1: Null distribution ---
axes[0].hist(null_distribution, bins=100, color="steelblue",
             edgecolor="white", alpha=0.8)
axes[0].axvline(threshold_fwe_05, color="red", linestyle="--",
                linewidth=2, label=f"p<0.05 threshold (t={threshold_fwe_05:.2f})")
axes[0].axvline(threshold_fwe_01, color="darkred", linestyle="--",
                linewidth=2, label=f"p<0.01 threshold (t={threshold_fwe_01:.2f})")
axes[0].axvline(observed_t_masked.max(), color="green", linestyle="-",
                linewidth=2, label=f"Max observed t ({observed_t_masked.max():.2f})")
axes[0].set_xlabel("Max t-statistic", fontsize=12)
axes[0].set_ylabel("Count", fontsize=12)
axes[0].set_title("Null Distribution from Permutation Testing", fontsize=14)
axes[0].legend()

plt.tight_layout()
plt.show()

# --- Plot 2: Thresholded t-map ---
plotting.plot_glass_brain(
    observed_t_map,
    threshold=threshold_fwe_05,
    colorbar=True,
    title=f"Observed t-map (FWE corrected p<0.05, t>{threshold_fwe_05:.2f})",
    display_mode="lyrz",
    cmap="hot"
)

# --- Plot 3: Log p-value map ---
plotting.plot_stat_map(
    log_p_map,
    threshold=1.3,              # -log10(0.05) ≈ 1.3
    colorbar=True,
    title="Permutation -log10(p) map",
    display_mode="z",
    cut_coords=8,
    cmap="hot"
)

plt.show()
# Out:
# C:\Users\ducat\AppData\Local\Temp\ipykernel_6956\3149958657.py:31: UserWarning: empty mask
#   plotting.plot_stat_map(

# %%
from lib.mni_to_atlas import AtlasBrowser
import numpy as np

atlas = AtlasBrowser("AAL3")

# %%
from nilearn.reporting import get_clusters_table

table = get_clusters_table(
    observed_t_map, stat_threshold=threshold_fwe_05, cluster_threshold=1
)

pos = [np.array([x,y,z]) for (x,y,z) in zip(table['X'], table['Z'], table['Y'])]

regions = []

for p in pos:
    projected_coords = atlas.project_to_nearest(p)
    projected_regions = atlas.find_regions(projected_coords)

    regions.append(*projected_regions)

regions
# Out:
# ['Putamen_R',
#  'Fusiform_L',
#  'Supp_Motor_Area_R',
#  'Cerebellum_9_R',
#  'OFCpost_R',
#  'Cerebellum_10_R',
#  'Temporal_Pole_Mid_L',
#  'Cerebellum_9_L',
#  'Cerebellum_8_R',
#  'Temporal_Inf_R',
#  'Cerebellum_9_R',
#  'N_Acc_R',
#  'Temporal_Pole_Sup_L',
#  'OFCmed_R',
#  'Pallidum_R',
#  'Temporal_Pole_Mid_R',
#  'Temporal_Mid_R',
#  'Precentral_L',
#  'Temporal_Pole_Mid_L',
#  'Supp_Motor_Area_R',
#  'Caudate_L',
#  'Temporal_Pole_Mid_R',
#  'Temporal_Inf_R']

# %%
from nilearn.reporting import get_clusters_table

table = get_clusters_table(
    observed_t_map, stat_threshold=threshold_fwe_01, cluster_threshold=2
)

pos = [np.array([x,y,z]) for (x,y,z) in zip(table['X'], table['Z'], table['Y'])]

regions = []

for p in pos:
    projected_coords = atlas.project_to_nearest(p)
    projected_regions = atlas.find_regions(projected_coords)

    regions.append(*projected_regions)

regions
# Out:
# ['Fusiform_L', 'Supp_Motor_Area_R', 'Temporal_Pole_Sup_L']
